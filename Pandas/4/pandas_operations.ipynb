# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("placement - placement.csv")
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
# x = df.astype(int)  type conversion
df['cgpa'] = df['cgpa'].astype(int)
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
df['cgpa'] = df['cgpa'].add(10)
df
# Out:
#     cgpa  resume_score  placed
# 0     28          6.52       1
# 1     26          5.17       0
# 2     28          8.86       1
# 3     26          7.27       1
# 4     27          7.30       1
# ..   ...           ...     ...
# 95    26          6.38       0
# 96    28          7.76       1
# 97    26          7.78       0
# 98    28          5.63       1
# 99    26          6.61       0
#
# [100 rows x 3 columns]

# %%
df['cgpa'] = df['cgpa']+10
df
# Out:
#     cgpa  resume_score  placed
# 0     38          6.52       1
# 1     36          5.17       0
# 2     38          8.86       1
# 3     36          7.27       1
# 4     37          7.30       1
# ..   ...           ...     ...
# 95    36          6.38       0
# 96    38          7.76       1
# 97    36          7.78       0
# 98    38          5.63       1
# 99    36          6.61       0
#
# [100 rows x 3 columns]

# %%
r = df['cgpa'].mean()
r
# Out:
# np.float64(16.47)

# %%
s = df['cgpa'].median()
s
# Out:
# 16.0

# %%
g = df.filter(items = ['cgpa','placed'])
g
df[['cgpa', 'placed']]
# Out:
#     cgpa  placed
# 0     18       1
# 1     16       0
# 2     18       1
# 3     16       1
# 4     17       1
# ..   ...     ...
# 95    16       0
# 96    18       1
# 97    16       0
# 98    18       1
# 99    16       0
#
# [100 rows x 2 columns]

# %%
s = df.filter(items=[5,6], axis=0)  #  axis=0 means row wise operation
s
# Out:
#    cgpa  resume_score  placed
# 5    18          6.19       1
# 6    15          7.09       0

# %%
df.to_string()  # save in string
# Out:
# '    cgpa  resume_score  placed\n0     18          6.52       1\n1     16          5.17       0\n2     18          8.86       1\n3     16          7.27       1\n4     17          7.30       1\n5     18          6.19       1\n6     15          7.09       0\n7     16          6.29       0\n8     16          6.71       0\n9     17          7.12       1\n10    16          6.35       0\n11    15          6.54       0\n12    16          7.01       0\n13    18          5.09       1\n14    17          6.25       1\n15    18          5.93       1\n16    18          7.64       1\n17    17          8.71       1\n18    15          5.88       0\n19    16          8.11       1\n20    15          8.06       0\n21    16          7.64       0\n22    16          5.77       0\n23    16          7.13       0\n24    18          6.18       1\n25    17          5.68       1\n26    16          6.47       0\n27    15          6.15       0\n28    17          7.67       1\n29    16          7.30       0\n30   
# ...

# %%
d = df.to_dict()  # save in dictonary
# d

# %%
idx = df.columns 
idx
# Out:
# Index(['cgpa', 'resume_score', 'placed'], dtype='object')

# %%
label = df.columns[0]  # first column label 
label
# Out:
# 'cgpa'

# %%
df.columns.values  # array of labels
# Out:
# array(['cgpa', 'resume_score', 'placed'], dtype=object)

# %%
p = df.rename(columns={'cgpa' : 'updated_cgpa', 'resume_score' : 'semester_marks'})    # rename columns
p
# Out:
#     updated_cgpa  semester_marks  placed
# 0             18            6.52       1
# 1             16            5.17       0
# 2             18            8.86       1
# 3             16            7.27       1
# 4             17            7.30       1
# ..           ...             ...     ...
# 95            16            6.38       0
# 96            18            7.76       1
# 97            16            7.78       0
# 98            18            5.63       1
# 99            16            6.61       0
#
# [100 rows x 3 columns]

# %%
df['half'] = df['cgpa'].where(df['cgpa']>17, other=0)
df
# Out:
#     cgpa  resume_score  placed  half
# 0     18          6.52       1    18
# 1     16          5.17       0     0
# 2     18          8.86       1    18
# 3     16          7.27       1     0
# 4     17          7.30       1     0
# ..   ...           ...     ...   ...
# 95    16          6.38       0     0
# 96    18          7.76       1    18
# 97    16          7.78       0     0
# 98    18          5.63       1    18
# 99    16          6.61       0     0
#
# [100 rows x 4 columns]

# %% [markdown]
# #### Data
# ##### 1. Numerical
#     * Continous data
#     * We can divide further
#     * salary -> 20654.65, weight -> 40.6, distance, height, age
# ##### 2. Categorical
#     * Descrete data
#     * we can not divide further
#     * gender, marital status, number of employees in an office
